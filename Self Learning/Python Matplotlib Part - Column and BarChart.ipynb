# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = ['A','B','C','D','E']
y = np.random.randint(1000,9000,5)
# change the figure size
plt.subplots(figsize = (8,4))

# create a bar chart
plt.bar(x,y)

# add labels and title
plt.xlabel('Category')
plt.ylabel('Sales')
plt.title('Category by Sales using Column Chart')
plt.show()

# %% [markdown]
# # In Maptlotlib
#
# * Colors
# * Width
# * Border Style
# * Transparency
# * Labels and annotations
# * Gridlines

# %%
categories =  ['A','B','C','D','E']
sales = np.random.randint(1000,9000,5)

# Plot the data
# plt.bar(categories, sales, color = ['red','blue','green','yellow','purple'])
# plt.bar(categories, sales, color = ['red','blue','green','yellow','purple'], width = 0.5)
# plt.bar(categories, sales, edgecolor = 'black', linewidth = 2)
plt.bar(categories, sales, alpha = 0.5) # 0 to 1
plt.xlabel('Categories')
plt.ylabel('Sales')
plt.title("Column Chart Example")
plt.show()

# %%
colors = ['red','blue','green','yellow','purple']
edgecolor = 'black'
linewidth = 1.5
plt.subplots(figsize = (8,4))
plt.bar(categories, sales, color = colors, edgecolor = edgecolor, linewidth = linewidth, alpha = 0.5)
plt.xlabel('Categories')
plt.ylabel('Sales')
plt.title("Column Chart Example")

# Adding the data lables to the columns
for i, v in enumerate(sales):
    plt.text(i,v, str(v), color = 'red', ha = 'center', va = 'bottom')


plt.show()

# %%
for i, v in enumerate(sales):
    print(i, "and", v)
# Out:
# 0 and 2788
# 1 and 6364
# 2 and 4679
# 3 and 4748
# 4 and 7759

# %%
data1 = [3,5,1,6,4]
data2 = [2,6,3,5,7]

lables = ['A','B','C','D','E']
plt.subplots(figsize = (8,4))
plt.bar(lables, data1, label = 'Data 1')
plt.bar(lables, data2, label = 'Data 2', bottom = data1)

plt.title("Column chart with legends and grid lines")

plt.xlabel('Labels')
plt.ylabel('Data')

# adding a legend
plt.legend(loc = 3)

# adding grid lines to the chart
plt.grid(True)

plt.show()

# %%
plt.legend?
# Out:
# Signature: plt.legend(*args, **kwargs) -> 'Legend'
# Docstring:
# Place a legend on the Axes.
#
# Call signatures::
#
#     legend()
#     legend(handles, labels)
#     legend(handles=handles)
#     legend(labels)
#
# The call signatures correspond to the following different ways to use
# this method:
#
# **1. Automatic detection of elements to be shown in the legend**
#
# The elements to be added to the legend are automatically determined,
# when you do not pass in any extra arguments.
#
# In this case, the labels are taken from the artist. You can specify
# them either at artist creation or by calling the
# :meth:`~.Artist.set_label` method on the artist::
#
#     ax.plot([1, 2, 3], label='Inline label')
#     ax.legend()
#
# or::
#
#     line, = ax.plot([1, 2, 3])
#     line.set_label('Label via method')
#     ax.legend()
#
# .. note::
#     Specific artists can be excluded from the automatic legend element
#     selection by using a label starting with an underscore, "_".
# ...

# %% [markdown]
#  ===============   =============
#         Location String   Location Code
#         ===============   =============
#         'best'            0
#             'upper right'     1
#         'upper left'      2
#         'lower left'      3
#         'lower right'     4
#         'right'           5
#         'center left'     6
#         'center right'    7
#         'lower center'    8
#         'upper center'    9
#         'center'          10

# %%
x = [2,3,4,5,6,7]
y = [4,5,6,7,8,9]
plt.bar(x,y, color = '#091B39')
plt.show()

# %%
x = [2,3,4,5,6,7]
y = [4,5,6,7,8,9]
plt.barh(x,y, color = '#091B39')
plt.show()

# %%
# Creating H-Bar chart

fig, ax = plt.subplots(figsize = (6,4))
# plt.subplots() is a function that returns a tuple containing a figure and axes object(s). 
# Thus when using fig, ax = plt.subplots() you unpack this tuple into the variables fig and ax.
# Having fig is useful if you want to change figure-level attributes or save the figure as an 
# image file later (e.g. with fig.savefig('yourfilename.png')). You certainly don't have
#  to use the returned figure object but many people do use it later so it's common to see.
#  Also, all axes objects 
# (the objects that have plotting methods), have a parent figure object anyway, thus:
# ax.barh(categories, sales,color = '#091B39')
# fig = plt.figure()
# ax = fig.add_subplot(111)

# Adding data lables
for i, s in enumerate(sales):
    ax.text(s, i, str(s), ha = 'left', va = 'bottom')

ax.set_xlabel('Category')
ax.set_ylabel('Sales')
ax.set_title('H-Bar Chart')
plt.show()

# %%
# All the styles
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use("fivethirtyeight")

# %%
# Creating H-Bar chart

fig, ax = plt.subplots(figsize = (6,4))
ax.barh(categories, sales,color = '#091B39')

# Adding data lables
for i, s in enumerate(sales):
    ax.text(s, i, str(s), ha = 'left', va = 'bottom')

ax.set_xlabel('Category')
ax.set_ylabel('Sales')
ax.set_title('H-Bar Chart')
plt.show()

# %%
# Create Column Chart and Horizontal bar chart together

# sample data
x = np.array(['Germany','India','USA','Canada','France'])
y1 = np.array([10,20,30,40,50])
y2 = np.array([15,25,35,45,55])

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(nrows = 1, ncols=2, figsize = (16,4))

ax1.bar(x,y1, color = 'blue')
ax1.set_xlabel('Category')
ax1.set_ylabel('Values')
ax1.set_title('Column Chart')


ax2.barh(x,y2, color = 'orange')
ax2.set_xlabel('Category')
ax2.set_ylabel('Values')
ax2.set_title('Horizontal Bar Chart')

plt.tight_layout()

plt.show()

# %%
# sample data
x = np.array(['Germany','India','USA','Canada','France'])
y1 = np.random.randint(1000,9000,5)
y2 =np.random.randint(1000,9000,5)

# %%
# Define the x-axis positions for each bar
bar_width = 0.40
r1 = np.arange(len(x))
print(r1)
r2 = [float(x + bar_width) for x in r1]
print(r2)

fig, ax = plt.subplots()

ax.bar(r1, y1, color = 'blue', width = bar_width, edgecolor = 'black', label = 'y1')
ax.bar(r2, y2, color = 'red', width = bar_width, edgecolor = 'black', label = 'y2')

ax.set_xlabel('Quarter')
ax.set_ylabel('Sales')
ax.set_title('Quarterly Sales by Region')

ax.legend()

plt.show()
# Out:
# [0 1 2 3 4]
# [0.4, 1.4, 2.4, 3.4, 4.4]

# %%
labels = ['Category A','Category B','Category C', 'Category D']
values = [ 50,35,40,45]
errors  = [5,2,3,4]

fig, ax = plt.subplots()

ax.bar(labels,values,yerr = errors, align='edge', alpha = 0.5, ecolor = 'red', capsize = 5)

ax.set_xlabel('Category')
ax.set_ylabel('Values')
ax.set_title('Bar Chart with Error Bars')

plt.show()
